# %% [markdown]
# # Welcome to Modal notebooks!
#
# Write Python code and collaborate in real time. Your code runs in Modal's
# **serverless cloud**, and anyone in the same workspace can join.
#
# This notebook comes with some common Python libraries installed. Run
# cells with `Shift+Enter`.

# %%
import os
os.chdir("/root")
# !rm -rf /root/* /root/.* 2>/dev/null; true
# !git clone https://{GIT_TOKEN}@github.com/fishperson113/Exact_2026_Laplace-s_Red_Devils.git .
# !git checkout Son/Logic_Based_Educational_Queries
# Out:
# Cloning into '.'...
# remote: Enumerating objects: 3867, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 3867 (delta 61), reused 94 (delta 36), pack-reused 3699 (from 1)
# Receiving objects: 100% (3867/3867), 99.76 MiB | 28.48 MiB/s, done.
# Resolving deltas: 100% (1884/1884), done.
# branch 'Son/Logic_Based_Educational_Queries' set up to track 'origin/Son/Logic_Based_Educational_Queries'.
# Switched to a new branch 'Son/Logic_Based_Educational_Queries'

# %%
# !git config --global user.email "thaisoncbq@gmail.com"
# !git config --global user.email "sonbui25"
# !git checkout Son/Logic_Based_Educational_Queries

import os
os.chdir("/root/app/logic_solution/")
# !pwd
# Out:
# Already on 'Son/Logic_Based_Educational_Queries'
# Your branch is up to date with 'origin/Son/Logic_Based_Educational_Queries'.
# /root/app/logic_solution

# %%
# Load token từ file .env
from pathlib import Path

env_file = Path("/root/app/logic_solution/.env")
try:
    for line in env_file.read_text().splitlines():
        if line.startswith("HF_TOKEN"):
            key, val = line.split("=", 1)
            print(f"Found: {key}={val[:8]}...")
            # Set vào environment để các script dùng được
            import os
            os.environ["HF_TOKEN"] = val.strip()
            print("Loaded into os.environ")
except Exception as e:
    print(f"Error loading .env: {e}")

# %%
# !bash run.sh --input data/sample_input.json
# Out:
# ...
#   Logic Solution — Ensemble Inference
# ...
# Script dir : /root/app/logic_solution
#
# [1/4] Kiểm tra uv...
#   uv đã có: uv 0.5.14
#
# [2/4] Virtual environment: logic_env...
# Using CPython 3.12.6 interpreter at: /usr/local/bin/python3.12
# Creating virtual environment at: logic_env
#   Đã tạo logic_env.
#   Python: Python 3.12.6
#
# [3/4] Cài dependencies từ requirements.txt...
# Using Python 3.12.6 environment at: logic_env
# Resolved 78 packages in 893ms
# ⠙ Preparing packages... (0/78)
# ⠙ Preparing packages... (0/78)
# ⠙ Preparing packages... (0/78)
# pygments   ------------------------------     0 B/1.17 MiB
# ⠙ Preparing packages... (0/78)
# pyyaml     ------------------------------     0 B/788.94 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# ⠙ Preparing packages... (0/78)
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/788.94 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# ...
